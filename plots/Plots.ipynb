# %%
from huckel import Chain
import matplotlib.pyplot as plt

# %%
# Create a 10 atom chain
chain = Chain(10)
chain.plot_eigenvalues()

# Create a 10 atom ring
ring = Chain(10)
ring.close_ring()
ring.plot_eigenvalues()

plt.savefig('chain_vs_ring.jpg', dpi=800)

# %%
# Create a 10 atom chain
chain = Chain(1000)
chain.plot_eigenvalues()

# Create a 10 atom ring
ring = Chain(1000)
ring.close_ring()
ring.plot_eigenvalues()

plt.savefig('convergence_limit.jpg', dpi=800)

# %%
# Testing the influence alpha in the eigenvalues
chain = Chain(100)
chain.plot_eigenvalues()

chain_alpha_prime = Chain(100)
chain_alpha_prime.set_alpha_prime(1)
chain_alpha_prime.plot_eigenvalues(comment=r'$\alpha=1$')

chain_alpha_prime = Chain(100)
chain_alpha_prime.set_alpha_prime(2)
chain_alpha_prime.plot_eigenvalues(comment=r'$\alpha=2$')

plt.savefig('alpha_in_chain.jpg', dpi=600)

# %%
# Testing the influence of beta in the eigenvalues
chain = Chain(100)
chain.plot_eigenvalues()

chain_beta_minus = Chain(100)
chain_beta_minus.set_beta_minus(-1.5)
chain_beta_minus.plot_eigenvalues(comment=r'$\beta=-1.5$')

chain_beta_minus = Chain(100)
chain_beta_minus.set_beta_minus(-.5)
chain_beta_minus.plot_eigenvalues(comment=r'$\beta=-0.5$')

plt.savefig('chain_beta_eigenvaules.jpg', dpi=600)

# %%
# Testing the influence of beta in the eigenvalues
chain = Chain(1000)
chain.plot_eigenvalues()

chain_beta_minus = Chain(1000)
chain_beta_minus.set_beta_minus(-1.5)
chain_beta_minus.plot_eigenvalues(comment=r'$\beta=-1.5$')

chain_beta_minus = Chain(1000)
chain_beta_minus.set_beta_minus(-.5)
chain_beta_minus.plot_eigenvalues(comment=r'$\beta=-0.5$')
print(min(abs(chain_beta_minus.eigen[0])))
#plt.savefig('convergence_chain_beta_eigenvaules.jpg', dpi=600)
# Out:
# 0.500019581793285

# %%
# Testing the influence alpha in the eigenvalues for a ring
ring = Chain(20)
ring.close_ring()
ring.plot_eigenvalues()

ring_alpha_prime = Chain(20)
ring_alpha_prime.close_ring()
ring_alpha_prime.set_alpha_prime(1)
ring_alpha_prime.plot_eigenvalues(comment=r'$\alpha=1$')

ring_alpha_prime = Chain(20)
ring_alpha_prime.close_ring()
ring_alpha_prime.set_alpha_prime(-1)
ring_alpha_prime.plot_eigenvalues(comment=r'$\alpha=-1$')

plt.savefig('alpha_in_ring.jpg', dpi=600)

# %%
# Testing the influence of beta in the eigenvalues for a ring
ring = Chain(20)
ring.close_ring()
ring.plot_eigenvalues()

ring_beta_minus = Chain(20)
ring_beta_minus.close_ring()
ring_beta_minus.set_beta_minus(-1.5)
ring_beta_minus.plot_eigenvalues(comment=r'$\beta=-0.8$')

ring_beta_minus = Chain(20)
ring_beta_minus.close_ring()
ring_beta_minus.set_beta_minus(-.5)
ring_beta_minus.plot_eigenvalues(comment=r'$\beta=-0.5$')

plt.savefig('ring_beta_eigenvalues.jpg', dpi=600)

# %%
# Testing the influence of beta in the eigenvalues for a ring
ring = Chain(10)
ring.close_ring()
ring.plot_eigenvalues()

ring_beta_minus = Chain(10)
ring_beta_minus.close_ring()
ring_beta_minus.set_beta_minus(-1.5)
ring_beta_minus.plot_eigenvalues(comment=r'$\beta=-0.8$')

ring_beta_minus = Chain(10)
ring_beta_minus.close_ring()
ring_beta_minus.set_beta_minus(-.5)
ring_beta_minus.plot_eigenvalues(comment=r'$\beta=-0.5$')

# %%
chain = Chain(100)
chain.plot_eigenvectors(1)
chain.plot_eigenvectors(2)
chain.plot_eigenvectors(3)
plt.savefig('chain_eigenvectors.jpg', dpi=600)

# %%
ring =  Chain(100)
ring.close_ring()
ring.plot_eigenvectors(1)

ring.plot_eigenvectors(4)
ring.plot_eigenvectors(5)
plt.savefig('ring_eigenvectors.jpg', dpi=600)

# %%
ring =  Chain(5000)
ring.close_ring()
ring.plot_eigenvectors(1)

ring.plot_eigenvectors(4)
ring.plot_eigenvectors(5)
plt.savefig('aa.jpg', dpi=600)

# %%
chain = Chain(100)
chain.set_alpha_prime(1)
chain.plot_eigenvectors(1)
chain.plot_eigenvectors(2)
chain.plot_eigenvectors(3)
plt.savefig('chain_alpha_eigenvectors.jpg', dpi=600)

# %%
ring =  Chain(100)
ring.close_ring()
ring.set_alpha_prime(1)
ring.plot_eigenvectors(1)
ring.set_alpha_prime(2)
ring.plot_eigenvectors(1)
ring.plot_eigenvectors(2)
ring.plot_eigenvectors(3)
plt.savefig('ring_alpha_eigenvectors.jpg', dpi=600)

# %%
ring =  Chain(100)
ring.close_ring()
ring.set_alpha_prime(2)
ring.plot_eigenvectors(1)
ring.plot_eigenvectors(2)
ring.plot_eigenvectors(3)

# %%
chain = Chain(10)
chain.plot_eigenvectors(1, comment=r'$\beta=-1$')
chain.set_beta_minus(-1.5)
chain.plot_eigenvectors(1, comment=r'$\beta=-1.5$')
chain.set_beta_minus(-.5)
chain.plot_eigenvectors(1, comment=r'$\beta=-0.5$')
plt.savefig('chain_beta_eigenvectors.jpg', dpi=600)

# %%
chain = Chain(10)
chain.plot_eigenvectors(2, comment=r'$\beta=-1$')
chain.set_beta_minus(-1.5)
chain.plot_eigenvectors(2, comment=r'$\beta=-1.5$')
chain.set_beta_minus(-.5)
chain.plot_eigenvectors(2, comment=r'$\beta=-0.5$')
plt.savefig('chain_beta_eigenvectors.jpg', dpi=600)

# %%
ring =  Chain(200)
ring.close_ring()
ring.plot_eigenvectors(1, comment=r'$\beta=-1$')  # Default beta value
ring.set_beta_minus(-1.5)
ring.plot_eigenvectors(1, comment=r'$\beta=-1.5$')  # beta = -1.5
ring.set_beta_minus(-.5)
ring.plot_eigenvectors(1, comment=r'$\beta=-0.5$')  # beta = -0.5
plt.savefig('ring_beta_eigenvectors.jpg', dpi=600)

# %%
ring =  Chain(200)
ring.close_ring()
# ring.plot_eigenvectors(2, comment=r'$\beta=-1$')  
# ring.plot_eigenvectors(3, comment=r'$\beta=-1$') # Default beta value
ring.set_beta_minus(-1.5)
ring.plot_eigenvectors(2 )  # beta = -1.5
ring.plot_eigenvectors(3 )  # beta = -0.5
ring.plot_eigenvectors(4 )  # beta = -0.5
plt.legend(loc='upper left')
# ring.set_beta_minus(-.5)
# ring.plot_eigenvectors(2, comment=r'$\beta=-0.5$')  # beta = -0.5
# ring.plot_eigenvectors(3, comment=r'$\beta=-0.5$')  # beta = -0.5
plt.savefig('ring_beta_eigenvectors_2.jpg', dpi=600)
